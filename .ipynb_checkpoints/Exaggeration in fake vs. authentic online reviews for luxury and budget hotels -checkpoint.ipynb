# %%
import pandas as pd
import numpy as np

# %%
pwd
# Out:
# '/Users/prashanthreddy/Documents/Code/ML/Research/.ipynb_checkpoints'

# %%
data=pd.read_csv("../Hotel_Reviews.csv",header=0)

# %%
data.head()
# Out:
#   reviewer_display_name            reviewer_url  rating review_date  \
# 0               Alana C       /Profile/71alanac       5  2022-06-10
# 1          Ghaith (Gio)          /Profile/ghk78       5  2021-07-30
# 2               David C  /Profile/J1619FCdavidc       5  2022-06-09
# 3                Zeta S       /Profile/479zetas       5  2022-06-08
# 4               Elena T  /Profile/K7328TDelenat       5  2022-06-08
#
#                                    review_title  \
# 0                                Family holiday
# 1  Wonderful Holiday with amazing hospitality.
# 2                              On another level
# 3                                    Great stay
# 4                                    Best hotel
#
#                                          review_text date_of_stay  trip_type  \
# 0  Had a great 2 weeks, lots of fun, mini club wa...   2022-06-30        NaN
# 1  Since the first minute I started my holiday in...   2021-07-31        NaN
# ...

# %%
data
# Out:
#                         id             dateAdded           dateUpdated  \
# 0     AVwc252WIN2L1WUfpqLP  2016-10-30T21:42:42Z  2018-09-10T21:06:27Z
# 1     AVwc252WIN2L1WUfpqLP  2016-10-30T21:42:42Z  2018-09-10T21:06:27Z
# 2     AVwc252WIN2L1WUfpqLP  2016-10-30T21:42:42Z  2018-09-10T21:06:27Z
# 3     AVwdOclqIN2L1WUfti38  2015-11-28T19:19:35Z  2018-09-10T21:06:16Z
# 4     AVwdOclqIN2L1WUfti38  2015-11-28T19:19:35Z  2018-09-10T21:06:16Z
# ...                    ...                   ...                   ...
# 9995  AVwd4TMv_7pvs4fz-Ers  2016-03-24T11:44:15Z  2018-01-01T00:00:46Z
# 9996  AVwdRp4DIN2L1WUfuGZZ  2015-10-26T23:03:02Z  2018-01-01T00:00:44Z
# 9997  AVwd1TbkByjofQCxs6FH  2016-06-11T03:12:23Z  2018-01-01T00:00:44Z
# 9998  AVwdHbizIN2L1WUfsXto  2016-12-13T03:44:36Z  2018-01-01T00:00:43Z
# 9999  AVwddMfdIN2L1WUfwAue  2016-06-22T19:07:21Z  2018-01-01T00:00:43Z
#
#                   address                                         categories  \
# ...

# %%
# df = data[['reviewes.username', 'reviews.rating','reviews.title','reviews.text',]].copy()

# %%
df
# Out:
#      reviewer_display_name  rating  \
# 0                  Alana C       5
# 1             Ghaith (Gio)       5
# 2                  David C       5
# 3                   Zeta S       5
# 4                  Elena T       5
# ...                    ...     ...
# 2078           weluvturkey       5
# 2079              john-tia       5
# 2080              grace-ro       4
# 2081                  agro       2
# 2082          Seaside31883       5
#
#                                            review_title  \
# 0                                        Family holiday
# 1          Wonderful Holiday with amazing hospitality.
# 2                                      On another level
# 3                                            Great stay
# 4                                            Best hotel
# ...                                                 ...
# 2078                             the best hotel in lara
# 2079                                   A Brillant Hotel
# ...

# %%
df
# Out:
#      reviewer_display_name  rating  \
# 0                  Alana C       5
# 1             Ghaith (Gio)       5
# 2                  David C       5
# 3                   Zeta S       5
# 4                  Elena T       5
# ...                    ...     ...
# 2078           weluvturkey       5
# 2079              john-tia       5
# 2080              grace-ro       4
# 2081                  agro       2
# 2082          Seaside31883       5
#
#                                            review_title  \
# 0                                        Family holiday
# 1          Wonderful Holiday with amazing hospitality.
# 2                                      On another level
# 3                                            Great stay
# 4                                            Best hotel
# ...                                                 ...
# 2078                             the best hotel in lara
# 2079                                   A Brillant Hotel
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2083 entries, 0 to 2082
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   reviewer_display_name   2083 non-null   object
#  1   reviewer_url            2083 non-null   object
#  2   rating                  2083 non-null   int64
#  3   review_date             2083 non-null   object
#  4   review_title            2083 non-null   object
#  5   review_text             2083 non-null   object
#  6   date_of_stay            2080 non-null   object
#  7   trip_type               0 non-null      float64
#  8   additional_reviews      2083 non-null   object
#  9   helpful                 2083 non-null   int64
#  10  reviewer_username       2081 non-null   object
#  11  reviewer_contributions  2083 non-null   int64
#  12  reviewer_helpful        2083 non-null   int64
#  13  photos                  2083 non-null   int64
# ...

# %%
df=data.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 0 entries
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   reviewer_display_name   0 non-null      object
#  1   reviewer_url            0 non-null      object
#  2   rating                  0 non-null      int64
#  3   review_date             0 non-null      object
#  4   review_title            0 non-null      object
#  5   review_text             0 non-null      object
#  6   date_of_stay            0 non-null      object
#  7   trip_type               0 non-null      float64
#  8   additional_reviews      0 non-null      object
#  9   helpful                 0 non-null      int64
#  10  reviewer_username       0 non-null      object
#  11  reviewer_contributions  0 non-null      int64
#  12  reviewer_helpful        0 non-null      int64
#  13  photos                  0 non-null      int64
# ...
